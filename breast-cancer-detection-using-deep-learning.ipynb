# %% [markdown]
# ## *Step 1: Import Modules*

# %%
# !pip3 install graphviz
# !pip3 install ann_visualizer
# Out:
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (0.8.4)
# Collecting ann_visualizer
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
# Building wheels for collected packages: ann-visualizer
# done
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=ed11e63fe14c0d6b0d5148ff0e5f38dc328206faf9bcb1f1e1a79f2b82536b0a
#   Stored in directory: /root/.cache/pip/wheels/1b/fc/58/2ab1c3b30350105929308becddda4fb59b1358e54f985e1f4a
# Successfully built ann-visualizer
# Installing collected packages: ann-visualizer
# Successfully installed ann-visualizer-2.5

# %%
import numpy as np
import pandas as pd
import os
from glob import glob
import itertools
import fnmatch
import random
import matplotlib.pylab as plt
import seaborn as sns
import cv2
from PIL import Image
from ann_visualizer.visualize import ann_viz;

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
# %matplotlib inline

# %% [markdown]
# ## *Step 2: Explore Data*

# %%
# Adding path of all the images together 
imagePatches = glob('/kaggle/input/breast-histopathology-images/**/*.png', recursive=True)
for filename in imagePatches[0:10]:
    print(filename)
# Out:
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1851_y1251_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1451_y1551_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1101_y1301_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1301_y1251_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1651_y1101_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x2051_y1401_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x2051_y2401_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1601_y1751_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1751_y1251_class1.png
# /kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x2001_y1201_class1.png

# %%
image_sample = "/kaggle/input/breast-histopathology-images/12935/1/12935_idx5_x1301_y1251_class1.png"
dsize=(50,50)

image = cv2.imread(image_sample)
image = cv2.resize(image, dsize)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)); plt.axis('off')
# Out:
# (-0.5, 49.5, 49.5, -0.5)

# %% [markdown]
# ## *Step 3: Preprocess Data*

# %%
resized_images,labels_arr = [],[]
dsize=(50,50)
    
for img in imagePatches[0:20000]:
    full_size_image = cv2.imread(img)
    resized_images.append(cv2.resize(full_size_image, dsize, interpolation=cv2.INTER_CUBIC))
    labels_arr.append(int(img[-5]))

# %%
def describeData(a,b):
    print('Total number of images: {}'.format(len(a)))
    print('Number of IDC(-) Images: {}'.format(len(a)-np.sum(b)))
    print('Number of IDC(+) Images: {}'.format(np.sum(b)))
    print('Image shape (Width, Height, Channels): {}'.format(a[0].shape))
describeData(resized_images,labels_arr)
# Out:
# Total number of images: 20000
# Number of IDC(-) Images: 15701
# Number of IDC(+) Images: 4299
# Image shape (Width, Height, Channels): (50, 50, 3)

# %% [markdown]
# - The data is scaled from 0 to 256 but we want it to be scaled from 0 to 1.
# - We also want to set aside 20% of the data for testing.
# - And finally, we will use an undersampling strategy to deal with the imbalanced class sizes.

# %%
X=np.array(resized_images)
Y=pd.Series(labels_arr) 
X=X/255.0
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, )

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (16000, 50, 50, 3)
# Testing Data Shape: (4000, 50, 50, 3)

# %%
plt.title("Distribution of target classes")
sns.countplot(Y)

# %%
# Make Data 1D for compatability upsampling methods
image_shape = 50*50*3

X_train = X_train.reshape(X_train.shape[0], image_shape)
X_test = X_test.reshape(X_test.shape[0], image_shape)

# %%
print("Shape of flattened training data:",X_train.shape,"\nShape of flatened testing data: ",X_test.shape)
# Out:
# Shape of flattened training data: (16000, 7500)
# Shape of flatened testing data:  (4000, 7500)

# %%
# Deal with imbalanced class sizes below

# from imblearn.over_sampling import RandomOverSampler 
from imblearn.under_sampling import RandomUnderSampler

# Ros = RandomOverSampler(sampling_strategy='auto') 
Rus = RandomUnderSampler(sampling_strategy='auto')

X_trainRusFlat, Y_trainRus = Rus.fit_sample(X_train, Y_train)
X_testRusFlat, Y_testRus = Rus.fit_sample(X_test, Y_test)

#Reshape the images
X_trainRus = X_trainRusFlat.reshape(len(X_trainRusFlat),50,50,3)
X_testRus = X_testRusFlat.reshape(len(X_testRusFlat),50,50,3)

# Encode labels
Y_trainRus = to_categorical(Y_trainRus, num_classes = 2)
Y_testRus = to_categorical(Y_testRus, num_classes = 2)

# %%
print("New shape of Train data =",X_trainRus.shape)
print("New shape of Test data =",X_testRus.shape)
# Out:
# New shape of Train data = (6860, 50, 50, 3)
# New shape of Test data = (1738, 50, 50, 3)

# %% [markdown]
# ## *Step 4: Define Helper Functions for the Classification Task*

# %%
# Helper Functions  Learning Curves and Confusion Matrix 

class MetricsCheckpoint(Callback):
    """Callback that saves metrics after each epoch"""
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotLearningCurve():
    
    plt.figure(figsize=(10,6))
    metrics = np.load('logs.npy', allow_pickle=True)[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')
    
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('Number of epochs')

def plot_learning_curve(history):
    
    plt.figure(figsize=(10,6))
    
    #model accuracy
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    
    # model loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    
def plot_confusion_matrix(cm, normalize=False, cmap=plt.cm.Blues):
    title='Confusion matrix'
    classes = {0: 'IDC(-)', 1: 'IDC(+)'}
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ## *Step 5: Evaluate Classification Models*

# %%
def build_ANN(num_classes=2,input_shape = (50,50, 3)):
#     input_shape=(7500,)
    model=Sequential()
    model.add(Flatten(input_shape=input_shape))
    
    #first layer with 500 neurons and relu activation function 
    model.add(Dense(100, activation="relu"))
    
    #second layer with 500 neurons and relu activation function 
    model.add(Dense(100, activation="relu"))
    
    #third layer with 500 neurons and relu activation function 
    model.add(Dense(100, activation="relu"))
    
    #fourth layer with 500 neurons and relu activation function 
    model.add(Dense(100, activation="relu"))
    
    #fifth layer with 500 neurons and relu activation function 
    model.add(Dense(100, activation="relu"))
    
    #output sigmoid layer 
    model.add(Dense(num_classes, activation="sigmoid"))
        
    return model

# %%
def build_base_CNN(num_classes=2, input_shape = (50,50, 3)):
        
    model = Sequential()
    model.add(Conv2D(32, (5, 5), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(32, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='sigmoid'))
    
    return model

# %%
def build_final_CNN(num_classes=2, input_shape = (50,50, 3)):
    
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(3, 3))) 
    model.add(Dropout(0.2))
    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.3))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='sigmoid')) # output 1 value between 0 and 1 : probability to have cancer
      
    return model

# %%
def eval_model(model, a, b, c, d, model_name=None, Visualize=False):
    
    batch_size = 32
    epochs = 25
    
    model.compile(loss="binary_crossentropy", # Use binary crossentropy as a loss function  
                  optimizer="adam",
                  metrics=['accuracy'])
    
    model.summary()
    if Visualize:
        print("Visualizing your neural network.")
        ann_viz(model, title=model_name, filename=model_name)
    
    history = model.fit(a,b,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (c,d),
            callbacks = [MetricsCheckpoint('logs')])
    
    if model_name:
        model.save(model_name+".h5")
    
    score = model.evaluate(c,d, verbose=0)
    print('\n accuracy:', score[1],'\n')
    
    y_pred = model.predict(c)
    map_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
    
    print('\n', classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1), target_names=list(map_characters.values())), sep='')    
    Y_pred_classes = np.argmax(y_pred,axis=1) 
    
    Y_true = np.argmax(d,axis=1) 
    
    plotLearningCurve()
    plt.show()  
    plot_learning_curve(history)
    plt.show()
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
    plot_confusion_matrix(confusion_mtx) 
    plt.show()

# %%
eval_model(build_ANN(),X_trainRusFlat, Y_trainRus, X_testRusFlat, Y_testRus, 'ANN')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 7500)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               750100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 790,702
# Trainable params: 790,702
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 215/215 [==============================] - 1s 7ms/step - loss: 0.6626 - accuracy: 0.5879 - val_loss: 0.5431 - val_accuracy: 0.7468
# Epoch 2/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.5389 - accuracy: 0.7382 - val_loss: 0.4187 - val_accuracy: 0.8303
# Epoch 3/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4861 - accuracy: 0.7892 - val_loss: 0.5743 - val_accuracy: 0.6715
# Epoch 4/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4771 - accuracy: 0.7878 - val_loss: 0.4882 - val_accuracy: 0.7722
# Epoch 5/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4580 - accuracy: 0.8020 - val_loss: 0.4463 - val_accuracy: 0.8113
# Epoch 6/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4632 - accuracy: 0.8004 - val_loss: 0.5044 - val_accuracy: 0.7911
# Epoch 7/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4557 - accuracy: 0.7987 - val_loss: 0.4335 - val_accuracy: 0.8268
# Epoch 8/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4631 - accuracy: 0.8004 - val_loss: 0.4405 - val_accuracy: 0.8234
# Epoch 9/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4413 - accuracy: 0.8141 - val_loss: 0.4357 - val_accuracy: 0.8188
# Epoch 10/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4496 - accuracy: 0.8089 - val_loss: 0.4221 - val_accuracy: 0.8268
# Epoch 11/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4477 - accuracy: 0.8105 - val_loss: 0.4157 - val_accuracy: 0.8297
# Epoch 12/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4431 - accuracy: 0.8121 - val_loss: 0.4404 - val_accuracy: 0.8165
# Epoch 13/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4285 - accuracy: 0.8198 - val_loss: 0.4196 - val_accuracy: 0.8274
# Epoch 14/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4381 - accuracy: 0.8141 - val_loss: 0.4266 - val_accuracy: 0.8239
# Epoch 15/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4273 - accuracy: 0.8181 - val_loss: 0.4228 - val_accuracy: 0.8303
# Epoch 16/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4307 - accuracy: 0.8171 - val_loss: 0.4199 - val_accuracy: 0.8239
# Epoch 17/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4360 - accuracy: 0.8160 - val_loss: 0.4166 - val_accuracy: 0.8280
# Epoch 18/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4368 - accuracy: 0.8120 - val_loss: 0.4894 - val_accuracy: 0.7796
# Epoch 19/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4335 - accuracy: 0.8138 - val_loss: 0.4172 - val_accuracy: 0.8285
# Epoch 20/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4179 - accuracy: 0.8257 - val_loss: 0.4681 - val_accuracy: 0.7923
# Epoch 21/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4239 - accuracy: 0.8181 - val_loss: 0.4394 - val_accuracy: 0.8130
# Epoch 22/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4168 - accuracy: 0.8227 - val_loss: 0.4336 - val_accuracy: 0.8078
# Epoch 23/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4282 - accuracy: 0.8133 - val_loss: 0.4525 - val_accuracy: 0.8130
# Epoch 24/25
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4184 - accuracy: 0.8198 - val_loss: 0.4398 - val_accuracy: 0.8199
# Epoch 25/25
# 215/215 [==============================] - 1s 5ms/step - loss: 0.4281 - accuracy: 0.8168 - val_loss: 0.4198 - val_accuracy: 0.8268
#
#  accuracy: 0.8268124461174011
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.84      0.81      0.82       869
#       IDC(+)       0.82      0.84      0.83       869
#
#     accuracy                           0.83      1738
#    macro avg       0.83      0.83      0.83      1738
# weighted avg       0.83      0.83      0.83      1738

# %%
eval_model(build_base_CNN(),X_trainRus, Y_trainRus, X_testRus, Y_testRus, 'base_CNN', True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 19, 19, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 9, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                165952
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 194,146
# Trainable params: 194,146
# Non-trainable params: 0
# _________________________________________________________________
# Visualizing your neural network.
# Epoch 1/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.6485 - accuracy: 0.6029 - val_loss: 0.4807 - val_accuracy: 0.7952
# Epoch 2/25
# 215/215 [==============================] - 17s 77ms/step - loss: 0.4925 - accuracy: 0.7869 - val_loss: 0.4649 - val_accuracy: 0.8049
# Epoch 3/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4704 - accuracy: 0.8006 - val_loss: 0.4412 - val_accuracy: 0.8147
# Epoch 4/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4745 - accuracy: 0.7969 - val_loss: 0.4781 - val_accuracy: 0.8285
# Epoch 5/25
# 215/215 [==============================] - 17s 77ms/step - loss: 0.4540 - accuracy: 0.8085 - val_loss: 0.4173 - val_accuracy: 0.8320
# Epoch 6/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4480 - accuracy: 0.8111 - val_loss: 0.4592 - val_accuracy: 0.8147
# Epoch 7/25
# 215/215 [==============================] - 16s 75ms/step - loss: 0.4465 - accuracy: 0.8122 - val_loss: 0.5079 - val_accuracy: 0.7704
# Epoch 8/25
# 215/215 [==============================] - 17s 77ms/step - loss: 0.4545 - accuracy: 0.8054 - val_loss: 0.4142 - val_accuracy: 0.8291
# Epoch 9/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.4517 - accuracy: 0.8130 - val_loss: 0.5315 - val_accuracy: 0.7526
# Epoch 10/25
# 215/215 [==============================] - 17s 79ms/step - loss: 0.4498 - accuracy: 0.8108 - val_loss: 0.4505 - val_accuracy: 0.8113
# Epoch 11/25
# 215/215 [==============================] - 17s 77ms/step - loss: 0.4487 - accuracy: 0.8106 - val_loss: 0.4784 - val_accuracy: 0.7785
# Epoch 12/25
# 215/215 [==============================] - 17s 81ms/step - loss: 0.4300 - accuracy: 0.8187 - val_loss: 0.4684 - val_accuracy: 0.8119
# Epoch 13/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.4340 - accuracy: 0.8159 - val_loss: 0.4004 - val_accuracy: 0.8343
# Epoch 14/25
# 215/215 [==============================] - 16s 75ms/step - loss: 0.4390 - accuracy: 0.8128 - val_loss: 0.4072 - val_accuracy: 0.8314
# Epoch 15/25
# 215/215 [==============================] - 16s 77ms/step - loss: 0.4535 - accuracy: 0.8096 - val_loss: 0.4005 - val_accuracy: 0.8314
# Epoch 16/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.4326 - accuracy: 0.8169 - val_loss: 0.3995 - val_accuracy: 0.8418
# Epoch 17/25
# 215/215 [==============================] - 17s 77ms/step - loss: 0.4303 - accuracy: 0.8162 - val_loss: 0.4087 - val_accuracy: 0.8320
# Epoch 18/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4256 - accuracy: 0.8201 - val_loss: 0.4271 - val_accuracy: 0.8216
# Epoch 19/25
# 215/215 [==============================] - 19s 90ms/step - loss: 0.4323 - accuracy: 0.8168 - val_loss: 0.4047 - val_accuracy: 0.8274
# Epoch 20/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.4227 - accuracy: 0.8201 - val_loss: 0.4011 - val_accuracy: 0.8400
# Epoch 21/25
# 215/215 [==============================] - 17s 78ms/step - loss: 0.4257 - accuracy: 0.8166 - val_loss: 0.3974 - val_accuracy: 0.8343
# Epoch 22/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4188 - accuracy: 0.8271 - val_loss: 0.3929 - val_accuracy: 0.8366
# Epoch 23/25
# 215/215 [==============================] - 17s 81ms/step - loss: 0.4225 - accuracy: 0.8233 - val_loss: 0.4083 - val_accuracy: 0.8372
# Epoch 24/25
# 215/215 [==============================] - 16s 76ms/step - loss: 0.4219 - accuracy: 0.8236 - val_loss: 0.3989 - val_accuracy: 0.8320
# Epoch 25/25
# 215/215 [==============================] - 17s 80ms/step - loss: 0.4099 - accuracy: 0.8324 - val_loss: 0.3845 - val_accuracy: 0.8464
#
#  accuracy: 0.8463751673698425
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.84      0.86      0.85       869
#       IDC(+)       0.86      0.83      0.84       869
#
#     accuracy                           0.85      1738
#    macro avg       0.85      0.85      0.85      1738
# weighted avg       0.85      0.85      0.85      1738

# %%
eval_model(build_final_CNN(),X_trainRus, Y_trainRus, X_testRus, Y_testRus, 'final_CNN', True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 48, 48, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 150,850
# Trainable params: 150,850
# Non-trainable params: 0
# _________________________________________________________________
# Visualizing your neural network.
# Epoch 1/25
# 215/215 [==============================] - 9s 40ms/step - loss: 0.5477 - accuracy: 0.7252 - val_loss: 0.4670 - val_accuracy: 0.8274
# Epoch 2/25
# 215/215 [==============================] - 8s 37ms/step - loss: 0.4717 - accuracy: 0.7968 - val_loss: 0.4878 - val_accuracy: 0.8297
# Epoch 3/25
# 215/215 [==============================] - 8s 39ms/step - loss: 0.4452 - accuracy: 0.8133 - val_loss: 0.3916 - val_accuracy: 0.8470
# Epoch 4/25
# 215/215 [==============================] - 9s 41ms/step - loss: 0.4293 - accuracy: 0.8184 - val_loss: 0.4062 - val_accuracy: 0.8441
# Epoch 5/25
# 215/215 [==============================] - 8s 36ms/step - loss: 0.4293 - accuracy: 0.8211 - val_loss: 0.3927 - val_accuracy: 0.8354
# Epoch 6/25
# 215/215 [==============================] - 8s 37ms/step - loss: 0.4203 - accuracy: 0.8220 - val_loss: 0.3945 - val_accuracy: 0.8389
# Epoch 7/25
# 215/215 [==============================] - 8s 39ms/step - loss: 0.4158 - accuracy: 0.8264 - val_loss: 0.4033 - val_accuracy: 0.8366
# Epoch 8/25
# 215/215 [==============================] - 9s 42ms/step - loss: 0.3990 - accuracy: 0.8345 - val_loss: 0.3739 - val_accuracy: 0.8562
# Epoch 9/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3935 - accuracy: 0.8389 - val_loss: 0.4194 - val_accuracy: 0.8239
# Epoch 10/25
# 215/215 [==============================] - 9s 40ms/step - loss: 0.3892 - accuracy: 0.8413 - val_loss: 0.3588 - val_accuracy: 0.8562
# Epoch 11/25
# 215/215 [==============================] - 9s 40ms/step - loss: 0.3929 - accuracy: 0.8363 - val_loss: 0.3573 - val_accuracy: 0.8585
# Epoch 12/25
# 215/215 [==============================] - 9s 42ms/step - loss: 0.3885 - accuracy: 0.8405 - val_loss: 0.3674 - val_accuracy: 0.8521
# Epoch 13/25
# 215/215 [==============================] - 8s 37ms/step - loss: 0.3835 - accuracy: 0.8414 - val_loss: 0.3639 - val_accuracy: 0.8533
# Epoch 14/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3804 - accuracy: 0.8421 - val_loss: 0.3564 - val_accuracy: 0.8567
# Epoch 15/25
# 215/215 [==============================] - 8s 37ms/step - loss: 0.3779 - accuracy: 0.8437 - val_loss: 0.3665 - val_accuracy: 0.8527
# Epoch 16/25
# 215/215 [==============================] - 9s 43ms/step - loss: 0.3772 - accuracy: 0.8420 - val_loss: 0.3694 - val_accuracy: 0.8596
# Epoch 17/25
# 215/215 [==============================] - 8s 37ms/step - loss: 0.3701 - accuracy: 0.8499 - val_loss: 0.3740 - val_accuracy: 0.8579
# Epoch 18/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3628 - accuracy: 0.8506 - val_loss: 0.3452 - val_accuracy: 0.8573
# Epoch 19/25
# 215/215 [==============================] - 8s 36ms/step - loss: 0.3662 - accuracy: 0.8517 - val_loss: 0.3739 - val_accuracy: 0.8550
# Epoch 20/25
# 215/215 [==============================] - 8s 39ms/step - loss: 0.3641 - accuracy: 0.8526 - val_loss: 0.4588 - val_accuracy: 0.8188
# Epoch 21/25
# 215/215 [==============================] - 9s 40ms/step - loss: 0.3614 - accuracy: 0.8531 - val_loss: 0.3944 - val_accuracy: 0.8418
# Epoch 22/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3618 - accuracy: 0.8531 - val_loss: 0.3514 - val_accuracy: 0.8613
# Epoch 23/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3535 - accuracy: 0.8628 - val_loss: 0.3776 - val_accuracy: 0.8562
# Epoch 24/25
# 215/215 [==============================] - 8s 38ms/step - loss: 0.3505 - accuracy: 0.8555 - val_loss: 0.3715 - val_accuracy: 0.8521
# Epoch 25/25
# 215/215 [==============================] - 9s 42ms/step - loss: 0.3581 - accuracy: 0.8552 - val_loss: 0.3452 - val_accuracy: 0.8625
#
#  accuracy: 0.8624855875968933
#
#
#               precision    recall  f1-score   support
#
#       IDC(-)       0.85      0.88      0.86       869
#       IDC(+)       0.87      0.85      0.86       869
#
#     accuracy                           0.86      1738
#    macro avg       0.86      0.86      0.86      1738
# weighted avg       0.86      0.86      0.86      1738

# %%
annmodel = load_model('ANN.h5')
base_cnnmodel = load_model('base_CNN.h5')
final_cnnmodel = load_model('final_CNN.h5')

# %%
#function to plot image
def img_plot(arr,index=0):
    plt.title('Test Image')
    plt.imshow(arr[index])

# %% [markdown]
# ## Test Case 1

# %%
index1 = 51
img_plot(X_testRus, index1)

# %%
input1 = X_testRus[index1:index1+1]
print('Input Index =',index1)
# Out:
# Input Index = 51

# %%
label1 = Y_testRus[index1].argmax()
annpred1 = annmodel.predict(input1)[0].argmax()
base_cnnpred1 = base_cnnmodel.predict(input1)[0].argmax()
final_cnnpred1 = final_cnnmodel.predict(input1)[0].argmax()

print('Predicted Value using ann model',annpred1)
print('Predicted Value using base cnn model',base_cnnpred1)
print('Predicted Value using final cnn model',final_cnnpred1)

print("\nTrue Value",label1)
# Out:
# Predicted Value using ann model 0
# Predicted Value using base cnn model 0
# Predicted Value using final cnn model 0
#
# True Value 0

# %% [markdown]
# ## Test Case 2

# %%
index2 = 402
img_plot(X_testRus, index2)

# %%
input2 = X_testRus[index2:index2+1]
print('Input Index =',index2)
# Out:
# Input Index = 402

# %%
label2 = Y_testRus[index2].argmax()
annpred2 = annmodel.predict(input2)[0].argmax()
base_cnnpred2 = base_cnnmodel.predict(input2)[0].argmax()
final_cnnpred2 = final_cnnmodel.predict(input2)[0].argmax()

print('Predicted Value using ann model',annpred2)
print('Predicted Value using base cnn model',base_cnnpred2)
print('Predicted Value using final cnn model',final_cnnpred2)
print("\nTrue Value",label2)
# Out:
# Predicted Value using ann model 0
# Predicted Value using base cnn model 0
# Predicted Value using final cnn model 0
#
# True Value 0
